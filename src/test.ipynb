# %%
import pandas as pd
from embeddings import TFIDFEmbedding, CharNgramEmbedding
import numpy as np

embedding_model = CharNgramEmbedding('../processed_data/chargram_embedding.pkl')
embedding_model.vocab_index
# Out:
# {' (K': 0,
#  ' (L': 1,
#  ' (M': 2,
#  ' (Y': 3,
#  ' (c': 4,
#  ' (n': 5,
#  ' 1 ': 6,
#  ' 10': 7,
#  ' 11': 8,
#  ' 12': 9,
#  ' 13': 10,
#  ' 14': 11,
#  ' 15': 12,
#  ' 16': 13,
#  ' 17': 14,
#  ' 18': 15,
#  ' 19': 16,
#  ' 1A': 17,
#  ' 20': 18,
#  ' 21': 19,
#  ' 22': 20,
#  ' 23': 21,
#  ' 24': 22,
#  ' 25': 23,
#  ' 26': 24,
#  ' 27': 25,
#  ' 28': 26,
#  ' 29': 27,
#  ' 30': 28,
#  ' 31': 29,
#  ' 32': 30,
#  ' 33': 31,
#  ' 34': 32,
#  ' 35': 33,
#  ' 36': 34,
#  ' 37': 35,
#  ' 38': 36,
#  ' 7 ': 37,
#  ' Am': 38,
#  ' An': 39,
#  ' Ba': 40,
#  ' Bi': 41,
#  ' Bà': 42,
#  ' Bá': 43,
#  ' Bì': 44,
#  ' Bí': 45,
#  ' Bô': 46,
#  ' Bư': 47,
#  ' Bạ': 48,
#  ' Bả': 49,
#  ' Bậ': 50,
#  ' Bắ': 51,
#  ' Bằ': 52,
#  ' Bỉ': 53,
#  ' Bồ': 54,
#  ' Bổ': 55,
#  ' Bộ': 56,
#  ' Bử': 57,
#  ' Ca': 58,
#  ' Ch': 59,
#  ' Cu': 60,
#  ' Cá': 61,
#  ' Cô': 62,
#  ' Cú': 63,
#  ' Cơ': 64,
#  ' Cư': 65,
#  ' Cả': 66,
#  ' Cấ': 67,
#  ' Cầ': 68,
#  ' Cẩ': 69,
#  ' Cậ': 70,
#  ' Cố': 71,
#  ' Củ': 72,
#  ' Cừ': 73,
#  ' Cử': 74,
#  ' Cự': 75,
#  ' Di': 76,
#  ' Do': 77,
#  ' Du': 78,
#  ' Dũ': 79,
#  ' Dư': 80,
#  ' Dầ': 81,
#  ' Dậ': 82,
#  ' Dị': 83,
#  ' Dụ': 84,
#  ' Dữ': 85,
#  ' Dự': 86,
#  ' Gi': 87,
#  ' Ha': 88,
#  ' He': 89,
#  ' Hi': 90,
#  ' Ho': 91,
#  ' Hu': 92,
#  ' Hy': 93,
#  ' Hà': 94,
#  ' Há': 95,
#  ' Hâ': 96,
#  ' Hã': 97,
#  ' Hò': 98,
#  ' Hó': 99,
#  ' Hù': 100,
#  ' Hư': 101,
#  ' Hạ': 102,
#  ' Hả': 103,
#  ' Hắ': 104,
#  ' Họ': 105,
#  ' Hồ': 106,
#  ' Hổ': 107,
#  ' Hộ': 108,
#  ' Hớ': 109,
#  ' Hợ': 110,
#  ' Hữ': 111,
#  ' Kh': 112,
#  ' Ki': 113,
#  ' Kè': 114,
#  ' Kí': 115,
#  ' Ký': 116,
#  ' Kế': 117,
#  ' Kỳ': 118,
#  ' La': 119,
#  ' Li': 120,
#  ' Lo': 121,
#  ' Lu': 122,
#  ' Ly': 123,
#  ' Là': 124,
#  ' Lâ': 125,
#  ' Lã': 126,
#  ' Lê': 127,
#  ' Lý': 128,
#  ' Lă': 129,
#  ' Lĩ': 130,
#  ' Lơ': 131,
#  ' Lư': 132,
#  ' Lạ': 133,
#  ' Lậ': 134,
#  ' Lễ': 135,
#  ' Lệ': 136,
#  ' Lị': 137,
#  ' Lỗ': 138,
#  ' Lộ': 139,
#  ' Lợ': 140,
#  ' Lữ': 141,
#  ' Lự': 142,
#  ' Ma': 143,
#  ' Mi': 144,
#  ' Mo': 145,
#  ' Mâ': 146,
#  ' Mô': 147,
#  ' Mạ': 148,
#  ' Mẫ': 149,
#  ' Mậ': 150,
#  ' Mặ': 151,
#  ' Mọ': 152,
#  ' Mộ': 153,
#  ' Mớ': 154,
#  ' Mỡ': 155,
#  ' Mụ': 156,
#  ' Mỹ': 157,
#  ' Na': 158,
#  ' Ng': 159,
#  ' Nh': 160,
#  ' Ni': 161,
#  ' Nà': 162,
#  ' Nô': 163,
#  ' Nú': 164,
#  ' Nă': 165,
#  ' Nư': 166,
#  ' Nẵ': 167,
#  ' Nể': 168,
#  ' Nỗ': 169,
#  ' Nữ': 170,
#  ' Oa': 171,
#  ' Oá': 172,
#  ' PH': 173,
#  ' Ph': 174,
#  ' Qu': 175,
#  ' Qú': 176,
#  ' Ri': 177,
#  ' Ro': 178,
#  ' Sa': 179,
#  ' Si': 180,
#  ' So': 181,
#  ' Su': 182,
#  ' Sá': 183,
#  ' Sâ': 184,
#  ' Sú': 185,
#  ' Sĩ': 186,
#  ' Sơ': 187,
#  ' Sư': 188,
#  ' Sậ': 189,
#  ' Sắ': 190,
#  ' Sở': 191,
#  ' Sỹ': 192,
#  ' Th': 193,
#  ' Ti': 194,
#  ' To': 195,
#  ' Tr': 196,
#  ' Tu': 197,
#  ' Tà': 198,
#  ' Tá': 199,
#  ' Tâ': 200,
#  ' Tí': 201,
#  ' Tò': 202,
#  ' Tô': 203,
#  ' Tù': 204,
#  ' Tú': 205,
#  ' Tă': 206,
#  ' Tĩ': 207,
#  ' Tư': 208,
#  ' Tạ': 209,
#  ' Tấ': 210,
#  ' Tầ': 211,
#  ' Tậ': 212,
#  ' Tế': 213,
#  ' Tề': 214,
#  ' Tị': 215,
#  ' Tố': 216,
#  ' Tổ': 217,
#  ' Tộ': 218,
#  ' Tụ': 219,
#  ' Tứ': 220,
#  ' Từ': 221,
#  ' Tử': 222,
#  ' Tự': 223,
#  ' Uy': 224,
#  ' Uẩ': 225,
#  ' Va': 226,
#  ' Vi': 227,
#  ' Và': 228,
#  ' Vâ': 229,
#  ' Vă': 230,
#  ' Vĩ': 231,
#  ' Vũ': 232,
#  ' Vư': 233,
#  ' Vạ': 234,
#  ' Vấ': 235,
#  ' Vị': 236,
#  ' Xi': 237,
#  ' Xu': 238,
#  ' Xí': 239,
#  ' Xư': 240,
#  ' Xả': 241,
#  ' Ye': 242,
#  ' Yê': 243,
#  ' cu': 244,
#  ' cũ': 245,
#  ' cư': 246,
#  ' cấ': 247,
#  ' dà': 248,
#  ' dâ': 249,
#  ' kế': 250,
#  ' lã': 251,
#  ' lộ': 252,
#  ' mạ': 253,
#  ' mớ': 254,
#  ' mỹ': 255,
#  ' nh': 256,
#  ' nố': 257,
#  ' ph': 258,
#  ' qu': 259,
#  ' sơ': 260,
#  ' th': 261,
#  ' tà': 262,
#  ' tă': 263,
#  ' vă': 264,
#  ' Ái': 265,
#  ' Án': 266,
#  ' Íc': 267,
#  ' Ôn': 268,
#  ' Đa': 269,
#  ' Đi': 270,
#  ' Đo': 271,
#  ' Đà': 272,
#  ' Đá': 273,
#  ' Đì': 274,
#  ' Đó': 275,
#  ' Đô': 276,
#  ' Đă': 277,
#  ' Đĩ': 278,
#  ' Đư': 279,
#  ' Đạ': 280,
#  ' Đả': 281,
#  ' Đẩ': 282,
#  ' Đắ': 283,
#  ' Đằ': 284,
#  ' Đặ': 285,
#  ' Đế': 286,
#  ' Đỉ': 287,
#  ' Đị': 288,
#  ' Đố': 289,
#  ' Đồ': 290,
#  ' Đổ': 291,
#  ' Đỗ': 292,
#  ' Độ': 293,
#  ' Đủ': 294,
#  ' Đứ': 295,
#  ' đì': 296,
#  '(Kh': 297,
#  '(Lo': 298,
#  '(Mo': 299,
#  '(Ye': 300,
#  '(cũ': 301,
#  '(nố': 302,
#  ', s': 303,
#  '/ C': 304,
#  '0/4': 305,
#  '1 (': 306,
#  '14B': 307,
#  '2 )': 308,
#  '2/9': 309,
#  '3/2': 310,
#  '30/': 311,
#  '372': 312,
#  '7 (': 313,
#  '72 ': 314,
#  'Ale': 315,
#  'An ': 316,
#  'Anh': 317,
#  'Ba ': 318,
#  'Ban': 319,
#  'Biê': 320,
#  'Biể': 321,
#  'Bà ': 322,
#  'Bài': 323,
#  'Bàn': 324,
#  'Bàu': 325,
#  'Bá ': 326,
#  'Bái': 327,
#  'Bát': 328,
#  'Bãi': 329,
#  'Bìn': 330,
#  'Bíc': 331,
#  'Bín': 332,
#  'Bôi': 333,
#  'Bôn': 334,
#  'Bùi': 335,
#  'Bưở': 336,
#  'Bạc': 337,
#  'Bạn': 338,
#  'Bạt': 339,
#  'Bản': 340,
#  'Bảo': 341,
#  'Bảy': 342,
#  'Bật': 343,
#  'Bắc': 344,
#  'Bằn': 345,
#  'Bế ': 346,
#  'Bỉn': 347,
#  'Bồn': 348,
#  'Bổn': 349,
#  'Bội': 350,
#  'Bờ ': 351,
#  'Bửu': 352,
#  'Ca ': 353,
#  'Cam': 354,
#  'Can': 355,
#  'Cao': 356,
#  'Chi': 357,
#  'Chu': 358,
#  'Chá': 359,
#  'Châ': 360,
#  'Chí': 361,
#  'Chú': 362,
#  'Chơ': 363,
#  'Chư': 364,
#  'Chấ': 365,
#  'Chế': 366,
#  'Cun': 367,
#  'Các': 368,
#  'Cán': 369,
#  'Cáp': 370,
#  'Cát': 371,
#  'Cô ': 372,
#  'Côn': 373,
#  'Cù ': 374,
#  'Cúc': 375,
#  'Cơ ': 376,
#  'Cư ': 377,
#  'Cươ': 378,
#  'Cản': 379,
#  'Cấn': 380,
#  'Cầm': 381,
#  'Cần': 382,
#  'Cẩm': 383,
#  'Cẩn': 384,
#  'Cận': 385,
#  'Cốn': 386,
#  'Cồn': 387,
#  'Cổ ': 388,
#  'Của': 389,
#  'Cửu': 390,
#  'Cự ': 391,
#  'Diê': 392,
#  'Diễ': 393,
#  'Diệ': 394,
#  'Doã': 395,
#  'Dun': 396,
#  'Duy': 397,
#  'Duẩ': 398,
#  'Duậ': 399,
#  'Dũn': 400,
#  'Dư ': 401,
#  'Dươ': 402,
#  'Dầu': 403,
#  'Dật': 404,
#  'Dị ': 405,
#  'Dục': 406,
#  'Dực': 407,
#  'Fra': 408,
#  'Gia': 409,
#  'Giá': 410,
#  'Giã': 411,
#  'Gió': 412,
#  'Giả': 413,
#  'Giấ': 414,
#  'H.6': 415,
#  'Hai': 416,
#  'Han': 417,
#  'Hen': 418,
#  'Hiê': 419,
#  'Hiế': 420,
#  'Hiề': 421,
#  'Hiể': 422,
#  'Hiệ': 423,
#  'Hoa': 424,
#  'Hoà': 425,
#  'Hoè': 426,
#  'Huy': 427,
#  'Huâ': 428,
#  'Huề': 429,
#  'Huệ': 430,
#  'Huỳ': 431,
#  'Hy ': 432,
#  'Hà ': 433,
#  'Hài': 434,
#  'Hàm': 435,
#  'Hàn': 436,
#  'Hào': 437,
#  'Hán': 438,
#  'Hân': 439,
#  'Hãn': 440,
#  'Hòa': 441,
#  'Hòe': 442,
#  'Hóa': 443,
#  'Hói': 444,
#  'Hùn': 445,
#  'Hú ': 446,
#  'Hưn': 447,
#  'Hưu': 448,
#  'Hươ': 449,
#  'Hướ': 450,
#  'Hườ': 451,
#  'Hưở': 452,
#  'Hạc': 453,
#  'Hạn': 454,
#  'Hạo': 455,
#  'Hải': 456,
#  'Hắc': 457,
#  'Hằn': 458,
#  'Học': 459,
#  'Hồ ': 460,
#  'Hồi': 461,
#  'Hồn': 462,
#  'Hộc': 463,
#  'Hớn': 464,
#  'Hợp': 465,
#  'Hữu': 466,
#  'I t': 467,
#  'II ': 468,
#  'III': 469,
#  'K20': 470,
#  'Kha': 471,
#  'Khe': 472,
#  'Khi': 473,
#  'Kho': 474,
#  'Khu': 475,
#  'Khá': 476,
#  'Khê': 477,
#  'Khô': 478,
#  'Khú': 479,
#  'Khư': 480,
#  'Khả': 481,
#  'Khắ': 482,
#  'Khở': 483,
#  'Kim': 484,
#  'Kin': 485,
#  'Kiê': 486,
#  'Kiề': 487,
#  'Kiể': 488,
#  'Kiệ': 489,
#  'Kín': 490,
#  'Kế ': 491,
#  'Kỳ ': 492,
#  'La ': 493,
#  'Lai': 494,
#  'Lam': 495,
#  'Lan': 496,
#  'Lin': 497,
#  'Liê': 498,
#  'Liễ': 499,
#  'Liệ': 500,
#  'Lon': 501,
#  'Los': 502,
#  'Luy': 503,
#  'Luậ': 504,
#  'Làn': 505,
#  'Lâm': 506,
#  'Lân': 507,
#  'Lã ': 508,
#  'Lãm': 509,
#  'Lãn': 510,
#  'Lão': 511,
#  'Lê ': 512,
#  'Lý ': 513,
#  'Lý(': 514,
#  'Lăn': 515,
#  'Lĩn': 516,
#  'Lơn': 517,
#  'Lư ': 518,
#  'Lưu': 519,
#  'Lươ': 520,
#  'Lượ': 521,
#  'Lạc': 522,
#  'Lập': 523,
#  'Lệ ': 524,
#  'Lịc': 525,
#  'Lỗ ': 526,
#  'Lỗi': 527,
#  'Lộ ': 528,
#  'Lộc': 529,
#  'Lợi': 530,
#  'Lựu': 531,
#  'Mai': 532,
#  'Man': 533,
#  'Min': 534,
#  'Miê': 535,
#  'Miế': 536,
#  'Mor': 537,
#  'Mân': 538,
#  'Mây': 539,
#  'Mạc': 540,
#  'Mại': 541,
#  'Mạn': 542,
#  'Mẫn': 543,
#  'Mậu': 544,
#  'Mặc': 545,
#  'Mặn': 546,
#  'Mẹ ': 547,
#  'Mọc': 548,
#  'Mộc': 549,
#  'Một': 550,
#  'Mới': 551,
#  'Mục': 552,
#  'Mỹ ': 553,
#  'Mỹ,': 554,
#  'Na ': 555,
#  'Nam': 556,
#  'Nga': 557,
#  'Ngh': 558,
#  'Ngu': 559,
#  'Ngy': 560,
#  'Ngâ': 561,
#  'Ngã': 562,
#  'Ngô': 563,
#  'Ngũ': 564,
#  'Ngạ': 565,
#  'Ngọ': 566,
#  'Ngữ': 567,
#  'Nha': 568,
#  'Nho': 569,
#  'Nhu': 570,
#  'Nhà': 571,
#  'Nhâ': 572,
#  'Nhã': 573,
#  'Nhì': 574,
#  'Nhĩ': 575,
#  'Nhơ': 576,
#  'Như': 577,
#  'Nhạ': 578,
#  'Nhấ': 579,
#  'Nhậ': 580,
#  'Nhị': 581,
#  'Nhữ': 582,
#  'Nin': 583,
#  'Non': 584,
#  'Nor': 585,
#  'Nàn': 586,
#  'Nôn': 587,
#  'Núi': 588,
#  'Núp': 589,
#  'Năm': 590,
#  'Năn': 591,
#  'Nơ ': 592,
#  'Nướ': 593,
#  'Nại': 594,
#  'Nẵn': 595,
#  'Nỗi': 596,
#  'Nữ ': 597,
#  'Oai': 598,
#  'Oán': 599,
#  'PHú': 600,
#  'PHư': 601,
#  'Pas': 602,
#  'Pha': 603,
#  'Phi': 604,
#  'Pho': 605,
#  'Phu': 606,
#  'Phá': 607,
#  'Phê': 608,
#  'Phò': 609,
#  'Phó': 610,
#  'Phù': 611,
#  'Phú': 612,
#  'Phư': 613,
#  'Phạ': 614,
#  'Phấ': 615,
#  'Phầ': 616,
#  'Phẩ': 617,
#  'Phổ': 618,
#  'Phụ': 619,
#  'Phủ': 620,
#  'Phứ': 621,
#  'Qua': 622,
#  'Quy': 623,
#  'Quá': 624,
#  'Quâ': 625,
#  'Quý': 626,
#  'Quả': 627,
#  'Quế': 628,
#  'Quố': 629,
#  'Quỳ': 630,
#  'Qúy': 631,
#  'Riê': 632,
#  'Ron': 633,
#  'San': 634,
#  'Sin': 635,
#  'Siê': 636,
#  'Son': 637,
#  'Soạ': 638,
#  'Sun': 639,
#  'Suố': 640,
#  'Sác': 641,
#  'Sán': 642,
#  'Sát': 643,
#  'Sáu': 644,
#  'Sâm': 645,
#  'Súy': 646,
#  'Sĩ ': 647,
#  'Sơn': 648,
#  'Sư ': 649,
#  'Sươ': 650,
#  'Sậy': 651,
#  'Sắc': 652,
#  'Sử ': 653,
#  'Sỹ ': 654,
#  'Tha': 655,
#  'Thi': 656,
#  'Tho': 657,
#  'Thu': 658,
#  'Thà': 659,
#  'Thá': 660,
#  'Thâ': 661,
#  'Thé': 662,
#  'Thê': 663,
#  'Thì': 664,
#  'Thí': 665,
#  'Thô': 666,
#  'Thù': 667,
#  'Thú': 668,
#  'Thă': 669,
#  'Thơ': 670,
#  'Thư': 671,
#  'Thạ': 672,
#  'Thả': 673,
#  'Thấ': 674,
#  'Thầ': 675,
#  'Thậ': 676,
#  'Thắ': 677,
#  'Thế': 678,
#  'Thỉ': 679,
#  'Thị': 680,
#  'Thọ': 681,
#  'Thố': 682,
#  'Thụ': 683,
#  'Thủ': 684,
#  'Thứ': 685,
#  'Thự': 686,
#  'Tiê': 687,
#  'Tiế': 688,
#  'Tiể': 689,
#  'Toá': 690,
#  'Toả': 691,
#  'Tra': 692,
#  'Tri': 693,
#  'Tru': 694,
#  'Trà': 695,
#  'Trá': 696,
#  'Trâ': 697,
#  'Trã': 698,
#  'Trí': 699,
#  'Trù': 700,
#  'Trư': 701,
#  'Trạ': 702,
#  'Trả': 703,
#  'Trầ': 704,
#  'Trị': 705,
#  'Trọ': 706,
#  'Trỗ': 707,
#  'Trứ': 708,
#  'Trừ': 709,
#  'Trự': 710,
#  'Tuy': 711,
#  'Tuâ': 712,
#  'Tuấ': 713,
#  'Tuệ': 714,
#  'Tài': 715,
#  'Tá ': 716,
#  'Tám': 717,
#  'Tâm': 718,
#  'Tân': 719,
#  'Tây': 720,
#  'Tíc': 721,
#  'Tín': 722,
#  'Tòn': 723,
#  'Tô ': 724,
#  'Tôn': 725,
#  'Tùn': 726,
#  'Tú ': 727,
#  'Túy': 728,
#  'Tăn': 729,
#  'Tĩn': 730,
#  'Tư ': 731,
#  'Tươ': 732,
#  'Tườ': 733,
#  'Tưở': 734,
#  'Tạ ': 735,
#  'Tạo': 736,
#  'Tản': 737,
#  'Tấn': 738,
#  'Tất': 739,
#  'Tần': 740,
#  'Tập': 741,
#  'Tế ': 742,
#  'Tịn': 743,
#  'Tố ': 744,
#  'Tốn': 745,
#  'Tốt': 746,
#  'Tụ ': 747,
#  'Từ ': 748,
#  'Tử ': 749,
#  'Tự ': 750,
#  'Tựu': 751,
#  'Uyê': 752,
#  'Uyể': 753,
#  'Uẩn': 754,
#  'Van': 755,
#  'Vin': 756,
#  'Viê': 757,
#  'Viế': 758,
#  'Việ': 759,
#  'Vàn': 760,
#  'Vân': 761,
#  'Võ ': 762,
#  'Vùn': 763,
#  'Văn': 764,
#  'Vĩn': 765,
#  'Vũ ': 766,
#  'Vũn': 767,
#  'Vươ': 768,
#  'Vạn': 769,
#  'Vấn': 770,
#  'Vịn': 771,
#  'Xiể': 772,
#  'Xu ': 773,
#  'Xuy': 774,
#  'Xuâ': 775,
#  'Xô ': 776,
#  'Xươ': 777,
#  'Xảo': 778,
#  'Yer': 779,
#  'Yêm': 780,
#  'Yên': 781,
#  'Yết': 782,
#  'a 1': 783,
#  'a 2': 784,
#  'a 3': 785,
#  'a 4': 786,
#  'a 5': 787,
#  'a 6': 788,
#  'a 7': 789,
#  'a 8': 790,
#  'a A': 791,
#  'a B': 792,
#  'a C': 793,
#  'a G': 794,
#  'a H': 795,
#  'a K': 796,
#  'a L': 797,
#  'a M': 798,
#  'a N': 799,
#  'a P': 800,
#  'a S': 801,
#  'a T': 802,
#  'a V': 803,
#  'a Đ': 804,
#  'a đ': 805,
#  'ai ': 806,
#  'am ': 807,
#  'an ': 808,
#  'anc': 809,
#  'and': 810,
#  'ang': 811,
#  'anh': 812,
#  'ao ': 813,
#  'ast': 814,
#  'by ': 815,
#  'by)': 816,
#  'c (': 817,
#  'c 1': 818,
#  'c 2': 819,
#  'c 3': 820,
#  'c 4': 821,
#  'c 5': 822,
#  'c 6': 823,
#  'c 7': 824,
#  'c 8': 825,
#  'c 9': 826,
#  'c A': 827,
#  'c B': 828,
#  'c C': 829,
#  'c D': 830,
#  'c H': 831,
#  'c K': 832,
#  'c L': 833,
#  'c M': 834,
#  'c N': 835,
#  'c P': 836,
#  'c Q': 837,
#  'c S': 838,
#  'c T': 839,
#  'c V': 840,
#  'c k': 841,
#  'c l': 842,
#  'c m': 843,
#  'c n': 844,
#  'c Đ': 845,
#  'ch ': 846,
#  'cis': 847,
#  'cun': 848,
#  'cuố': 849,
#  'côn': 850,
#  'cũ)': 851,
#  'cư ': 852,
#  'cấp': 853,
#  'dre': 854,
#  'dài': 855,
#  'dân': 856,
#  'e S': 857,
#  'e Y': 858,
#  'eby': 859,
#  'enr': 860,
#  'ers': 861,
#  'eur': 862,
#  'exa': 863,
#  'g (': 864,
#  'g 1': 865,
#  'g 2': 866,
#  'g 3': 867,
#  'g 4': 868,
#  'g 5': 869,
#  'g 6': 870,
#  'g 7': 871,
#  'g 8': 872,
#  'g 9': 873,
#  'g B': 874,
#  'g C': 875,
#  'g D': 876,
#  'g G': 877,
#  'g H': 878,
#  'g K': 879,
#  'g L': 880,
#  'g M': 881,
#  'g N': 882,
#  'g P': 883,
#  'g Q': 884,
#  'g S': 885,
#  'g T': 886,
#  'g V': 887,
#  'g X': 888,
#  'g c': 889,
#  'g t': 890,
#  'g Í': 891,
#  'g Đ': 892,
#  'ghi': 893,
#  'ghè': 894,
#  'ghĩ': 895,
#  'ghệ': 896,
#  'ghị': 897,
#  'guy': 898,
#  'gyễ': 899,
#  'gân': 900,
#  'gãi': 901,
#  'gô ': 902,
#  'gôn': 903,
#  'gũ ': 904,
#  'gạn': 905,
#  'gọc': 906,
#  'h (': 907,
#  'h 1': 908,
#  'h 2': 909,
#  'h 3': 910,
#  'h 4': 911,
#  'h 5': 912,
#  'h 6': 913,
#  'h 7': 914,
#  'h 8': 915,
#  'h 9': 916,
#  'h A': 917,
#  'h B': 918,
#  'h C': 919,
#  'h D': 920,
#  'h G': 921,
#  'h H': 922,
#  'h K': 923,
#  'h L': 924,
#  'h M': 925,
#  'h N': 926,
#  'h P': 927,
#  'h Q': 928,
#  'h S': 929,
#  'h T': 930,
#  'h U': 931,
#  'h V': 932,
#  'h X': 933,
#  'h m': 934,
#  'h p': 935,
#  'h q': 936,
#  'h t': 937,
#  'h Á': 938,
#  'h Ý': 939,
#  'h Đ': 940,
#  'h(c': 941,
#  'hai': 942,
#  'ham': 943,
#  'han': 944,
#  'he ': 945,
#  'hi ': 946,
#  'hin': 947,
#  'hiê': 948,
#  'hiế': 949,
#  'hiề': 950,
#  'hiể': 951,
#  'hiễ': 952,
#  'hiệ': 953,
#  'ho ': 954,
#  'hoa': 955,
#  'hon': 956,
#  'hoá': 957,
#  'hoạ': 958,
#  'hu ': 959,
#  'huy': 960,
#  'huê': 961,
#  'huậ': 962,
#  'huỷ': 963,
#  'hàn': 964,
#  'hác': 965,
#  'hái': 966,
#  'hám': 967,
#  'hán': 968,
#  'hát': 969,
#  'hân': 970,
#  'hâu': 971,
#  'hãn': 972,
#  'hè ': 973,
#  'hép': 974,
#  'hê ': 975,
#  'hêm': 976,
#  'hì ': 977,
#  'hí ': 978,
#  'híc': 979,
#  'hín': 980,
#  'hòn': 981,
#  'hó ': 982,
#  'hôi': 983,
#  'hôn': 984,
#  'hù ': 985,
#  'hùn': 986,
#  'hùy': 987,
#  'hú ': 988,
#  'húa': 989,
#  'húc': 990,
#  'húy': 991,
#  'hăn': 992,
#  'hĩa': 993,
#  'hơn': 994,
#  'hư ': 995,
#  'hươ': 996,
#  'hướ': 997,
#  'hườ': 998,
#  'hưở': 999,
#  ...}
